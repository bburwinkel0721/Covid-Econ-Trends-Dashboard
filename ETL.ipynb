# %%
import requests
import json
import pandas as pd
import numpy as np
from api_keys import bls_api_key

from pymongo import MongoClient
from pprint import pprint

# %%
# keys
bls_key = bls_api_key

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
bls_url = f'https://api.bls.gov/publicAPI/v2/timeseries/data/?registrationkey={bls_api_key}&catalog=true&startyear=2010&endyear=2014&calculations=true&annualaverage=true&aspects=true'
bls_url2 = 	'https://api.bls.gov/publicAPI/v2/timeseries/data/ISU00000000031004'
response = requests.get(bls_url2)
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'status': 'REQUEST_SUCCEEDED',
#  'responseTime': 168,
#  'message': [],
#  'Results': {'series': [{'seriesID': 'ISU00000000031004',
#     'data': [{'year': '2022',
#       'period': 'A01',
#       'periodName': 'Annual',
#       'latest': 'true',
#       'value': '3.2',
#       'footnotes': [{}]},
#      {'year': '2021',
#       'period': 'A01',
#       'periodName': 'Annual',
#       'value': '3.0',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'A01',
#       'periodName': 'Annual',
#       'value': '3.1',
#       'footnotes': [{}]}]}]}}

# %%
population_df = pd.read_csv('./Resources/NST-EST2023-ALLDATA.csv')
population_df.head(20)
# Out:
#     SUMLEV REGION DIVISION  STATE                NAME  ESTIMATESBASE2020  \
# 0       10      0        0      0       United States          331464948
# 1       20      1        0      0    Northeast Region           57614141
# 2       30      1        1      0         New England           15119994
# 3       30      1        2      0     Middle Atlantic           42494147
# 4       20      2        0      0      Midwest Region           68987296
# 5       30      2        3      0  East North Central           47369629
# 6       30      2        4      0  West North Central           21617667
# 7       20      3        0      0        South Region          126268529
# 8       30      3        5      0      South Atlantic           66091701
# 9       30      3        6      0  East South Central           19402683
# 10      30      3        7      0  West South Central           40774145
# 11      20      4        0      0         West Region           78594982
# ...

# %%
population_df = population_df[['NAME','POPESTIMATE2020','POPESTIMATE2021','POPESTIMATE2022','POPESTIMATE2023']]
population_df
# Out:
#                 NAME  POPESTIMATE2020  POPESTIMATE2021  POPESTIMATE2022  \
# 0      United States        331526933        332048977        333271411
# 1   Northeast Region         57430477         57243423         57026847
# 2        New England         15057898         15106108         15120739
# 3    Middle Atlantic         42372579         42137315         41906108
# 4     Midwest Region         68969794         68850246         68783028
# ..               ...              ...              ...              ...
# 61        Washington          7724566          7741433          7784477
# 62     West Virginia          1791562          1785249          1774035
# 63         Wisconsin          5896700          5879978          5890543
# 64           Wyoming           577664           579548           581629
# 65       Puerto Rico          3281557          3262693          3220113
#
#     POPESTIMATE2023
# 0         334914895
# 1          56983517
# 2          15159777
# ...
